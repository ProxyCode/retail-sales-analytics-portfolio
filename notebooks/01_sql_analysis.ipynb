# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('../data/interim/retail.db')

# %%
pd.read_sql('SELECT * FROM sales LIMIT 5', conn)
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
import sqlite3
import pandas as pd

# Connect to your database
conn = sqlite3.connect('../data/interim/retail.db')

# Check connection works
df = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
df
# Out:
#     name
# 0  sales

# %%
pd.read_sql("PRAGMA table_info('sales')", conn)
# Out:
#    cid   name     type  notnull dflt_value  pk
# 0    0   date     TEXT        0       None   0
# 1    1  store  INTEGER        0       None   0
# 2    2   item  INTEGER        0       None   0
# 3    3  sales  INTEGER        0       None   0

# %%
pd.read_sql("SELECT * FROM sales LIMIT 5", conn)
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
pd.read_sql("""
    SELECT store, SUM(sales) as total_sales
    FROM sales
    GROUP BY store
    ORDER BY total_sales DESC
    LIMIT 5
""", conn)
# Out:
#    store  total_sales
# 0      2       943732
# 1      8       787449
# 2      3       745232
# 3     10       720123
# 4      9       676693

# %%
# Look at the first 5 rows
df_sales = pd.read_sql("SELECT * FROM retail_sales LIMIT 5;", conn)
df_sales
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Projects/retail-sales-analytics-portfolio/.venv/lib/python3.13/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: retail_sales
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Look at the first 5 rows
# ----> 2 df_sales = pd.read_sql("SELECT * FROM retail_sales LIMIT 5;", conn)
#       3 df_sales
#
# File ~/Projects/retail-sales-analytics-portfolio/.venv/lib/python3.13/site-packages/pandas/io/sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File ~/Projects/retail-sales-analytics-portfolio/.venv/lib/python3.13/site-packages/pandas/io/sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~/Projects/retail-sales-analytics-portfolio/.venv/lib/python3.13/site-packages/pandas/io/sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT * FROM retail_sales LIMIT 5;': no such table: retail_sales

# %%
pd.read_sql("""
SELECT store, item, COUNT(*) as record_count
FROM retail_sales
GROUP BY store, item
ORDER BY record_count DESC
LIMIT 10;
""", conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Projects/retail-sales-analytics-portfolio/.venv/lib/python3.13/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: retail_sales
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pd.read_sql("""
#       2 SELECT store, item, COUNT(*) as record_count
#       3 FROM retail_sales
#       4 GROUP BY store, item
#       5 ORDER BY record_count DESC
#       6 LIMIT 10;
#       7 """, conn)
#
# File ~/Projects/retail-sales-analytics-portfolio/.venv/lib/python3.13/site-packages/pandas/io/sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File ~/Projects/retail-sales-analytics-portfolio/.venv/lib/python3.13/site-packages/pandas/io/sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~/Projects/retail-sales-analytics-portfolio/.venv/lib/python3.13/site-packages/pandas/io/sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT store, item, COUNT(*) as record_count
# FROM retail_sales
# GROUP BY store, item
# ORDER BY record_count DESC
# LIMIT 10;
# ': no such table: retail_sales

# %%
df_sales = pd.read_sql("SELECT * FROM sales LIMIT 5;", conn)
df_sales
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
sqlite-utils insert data/interim/retail.db sales data/raw/retail_sales_sample.csv --csv
# Out:
#   Cell In[8], line 1
#     sqlite-utils insert data/interim/retail.db sales data/raw/retail_sales_sample.csv --csv
#                  ^
# SyntaxError: invalid syntax

# %%
df_sales = pd.read_sql("SELECT * FROM sales LIMIT 5;", conn)
df_sales
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('data/interim/retail.db')

# See column names and types
schema = pd.read_sql("PRAGMA table_info(sales);", conn)
schema
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[10], line 4
#       1 import sqlite3
#       2 import pandas as pd
# ----> 4 conn = sqlite3.connect('data/interim/retail.db')
#       6 # See column names and types
#       7 schema = pd.read_sql("PRAGMA table_info(sales);", conn)
#
# OperationalError: unable to open database file

# %%
import os
os.getcwd()
# Out:
# '/Users/charlesroyes/Projects/retail-sales-analytics-portfolio/notebooks'

# %%
import sqlite3
import pandas as pd

# Correct relative path from notebooks/
conn = sqlite3.connect('../data/interim/retail.db')

# Test reading the table info
pd.read_sql("PRAGMA table_info(sales);", conn)
# Out:
#    cid   name     type  notnull dflt_value  pk
# 0    0   date     TEXT        0       None   0
# 1    1  store  INTEGER        0       None   0
# 2    2   item  INTEGER        0       None   0
# 3    3  sales  INTEGER        0       None   0

# %%
import os
os.getcwd()
# Out:
# '/Users/charlesroyes/Projects/retail-sales-analytics-portfolio/notebooks'

# %%
pd.read_sql("SELECT * FROM sales LIMIT 5;", conn)
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
pd.read_sql("SELECT COUNT(*) AS total_records FROM sales;", conn)
# Out:
#    total_records
# 0         149999

# %%
pd.read_sql("""
SELECT 
    SUM(CASE WHEN date IS NULL THEN 1 ELSE 0 END) AS missing_date,
    SUM(CASE WHEN store IS NULL THEN 1 ELSE 0 END) AS missing_store,
    SUM(CASE WHEN item IS NULL THEN 1 ELSE 0 END) AS missing_item,
    SUM(CASE WHEN sales IS NULL THEN 1 ELSE 0 END) AS missing_sales
FROM sales;
""", conn)
# Out:
#    missing_date  missing_store  missing_item  missing_sales
# 0             0              0             0              0

# %%
pd.read_sql("""
SELECT store, SUM(sales) AS total_sales, AVG(sales) AS avg_sales
FROM sales
GROUP BY store
ORDER BY total_sales DESC;
""", conn)
# Out:
#    store  total_sales  avg_sales
# 0      2       943732  57.425581
# 1      8       787449  53.905326
# 2      3       745232  50.099630
# 3     10       720123  49.296481
# 4      9       676693  46.323453
# 5      4       674761  46.191197
# 6      1       665977  40.524340
# 7      5       488624  33.449069
# 8      6       487905  33.399849
# 9      7       446709  30.579751

# %%
pd.read_sql("""
SELECT substr(date, 1, 7) AS month, SUM(sales) AS monthly_sales
FROM sales
GROUP BY month
ORDER BY month;
""", conn)
# Out:
#       month  monthly_sales
# 0   2013-01          63896
# 1   2013-02          65003
# 2   2013-03          87375
# 3   2013-04          96270
# 4   2013-05         107526
# 5   2013-06         112629
# 6   2013-07         120371
# 7   2013-08         108272
# 8   2013-09          96659
# 9   2013-10          91436
# 10  2013-11          96693
# 11  2013-12          70281
# 12  2014-01          72915
# 13  2014-02          73142
# 14  2014-03          98025
# 15  2014-04         109954
# 16  2014-05         122461
# 17  2014-06         126279
# 18  2014-07         137433
# 19  2014-08         122640
# 20  2014-09         108672
# 21  2014-10         105024
# 22  2014-11         110863
# 23  2014-12          80491
# 24  2015-01          76679
# 25  2015-02          76466
# 26  2015-03         101929
# 27  2015-04         114799
# 28  2015-05         128578
# 29  2015-06         130660
# 30  2015-07         143066
# 31  2015-08         128215
# 32  2015-09         114753
# 33  2015-10         110485
# 34  2015-11         114744
# 35  2015-12          84297
# 36  2016-01          83364
# 37  2016-02          85399
# 38  2016-03         109542
# 39  2016-04         125629
# 40  2016-05         137360
# 41  2016-06         142311
# 42  2016-07         158454
# 43  2016-08         136169
# 44  2016-09         124252
# 45  2016-10         120243
# 46  2016-11         123590
# 47  2016-12          92142
# 48  2017-01          85590
# 49  2017-02          86181
# 50  2017-03         113672
# 51  2017-04         130754
# 52  2017-05         141529
# 53  2017-06         148200
# 54  2017-07         162788
# 55  2017-08         142043
# 56  2017-09         129788
# 57  2017-10         123409
# 58  2017-11         128948
# 59  2017-12          96867
